# %%
import pandas as pd
from sklearn.decomposition import LatentDirichletAllocation, NMF
import matplotlib.pyplot as plt

# %%
file = pd.read_table('../steps/discrete.txt')

# %%
file.head()
# Out:
#          Sample  Chr  CN  SegSize  Dist2Cent  SegVal  LOH  SizeDipSeg  CpCN  \
# 0  TCGA-02-0001    1   3        6          4       5    0           2     3
# 1  TCGA-02-0001    2   3        5          5       6    0           1    10
# 2  TCGA-02-0001    3   2        5          5       5    0           1     4
# 3  TCGA-02-0001    4   2        6          3       2    0           4     2
# 4  TCGA-02-0001    5   2        5          6       3    0           3    13
#
#    Dist2nCNV  GCcSeg
# 0          6       4
# 1          1       3
# 2          3       2
# 3          2       1
# 4          2       2

# %%
file.shape
# Out:
# (23, 11)

# %%
X = file.drop(['Sample', 'Chr'], axis=1)
X.head()
# Out:
#    CN  SegSize  Dist2Cent  SegVal  LOH  SizeDipSeg  CpCN  Dist2nCNV  GCcSeg
# 0   3        6          4       5    0           2     3          6       4
# 1   3        5          5       6    0           1    10          1       3
# 2   2        5          5       5    0           1     4          3       2
# 3   2        6          3       2    0           4     2          2       1
# 4   2        5          6       3    0           3    13          2       2

# %%
def plot_top_words(model, n_components, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, int(round(n_components/2)), figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Signature {topic_idx +1}", fontdict={"fontsize": 30})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# %%
def lda_fit(df, n_components):
    # Removing columns with sample name and chromosome
    X = df.drop(['Sample', 'Chr'], axis = 1)
    
    # Fitting the model using the features
    model = LatentDirichletAllocation(
            n_components=n_components,
            max_iter=5,
            learning_method="online",
            learning_offset=50.0,
            random_state=0
            )

    fit = model.fit(X)
    
    return fit

def nmf_fit(df, n_components):
    # Removing columns with sample name and chromosome
    X = df.drop(['Sample', 'Chr'], axis = 1)
    
    # Fitting the model using the features
    model = NMF(
        n_components=n_components, 
        beta_loss="kullback-leibler",
        solver="mu",
        max_iter=1000,
        l1_ratio=0.5,
        random_state=0
        )
    
    fit = model.fit(X)
    
    return fit

# %%
n_samples = 23
n_features = 9
n_components = 8

# %%
fit = lda_fit(file, n_components)
plot_top_words(fit, n_components, X.columns, n_features, "Signatures in LDA model")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <module>
#       1 fit = lda_fit(file, n_components)
# ----> 2 plot_top_words(fit, n_components, X.columns, n_features, "Signatures in LDA model")
#
# Input In [6], in plot_top_words(model, n_components, feature_names, n_top_words, title)
#       2 fig, axes = plt.subplots(2, int(round(n_components/2)), figsize=(30, 15), sharex=True)
#       3 axes = axes.flatten()
# ----> 4 for topic_idx, topic in enumerate(model.components_):
#       5     top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
#       6     top_features = [feature_names[i] for i in top_features_ind]
#
# AttributeError: 'numpy.ndarray' object has no attribute 