# %%
import pandas as pd
import numpy as np
from gensim.models import LdaModel
from gensim import corpora
import seaborn as sns
import matplotlib.pylab as plt
from scipy.stats import pearsonr
from matplotlib.colors import ListedColormap

# %%
file = pd.read_table('../steps/discretized_9.features', dtype=str)

# %%
lda = LdaModel.load(f'../steps/gensim/lda/lda_t5_f10.model')
df = file.drop(['Sample', 'Chr'], axis = 1)
listedDf = df.values.tolist()
dirichlet_dict = corpora.Dictionary(listedDf)
bow_corpus = [dirichlet_dict.doc2bow(text) for text in listedDf]

# %%
def create_heatmap(model, df):
    topics = lda.get_document_topics(bow = bow_corpus, minimum_probability = 0)
    
    new_df = pd.DataFrame(df['Sample'])
    new_df['Chr'] = df['Chr']
    new_df['Chr'] = pd.to_numeric(new_df['Chr'])
    
    columns = [[],[],[],[],[]]
    for topic in topics:
        for w in topic:
            columns[w[0]].append(w[1])
    
    new_df['1'] = columns[0]
    new_df['2'] = columns[1]
    new_df['3'] = columns[2]
    new_df['4'] = columns[3]
    new_df['5'] = columns[4]
    new_df = new_df.sort_values(by='Chr')
    return new_df

# %%
weights_df = create_heatmap(lda, file)
heatmap_df = weights_df.drop('Sample', axis = 1).set_index('Chr').transpose()
heatmap_df
# Out:
# Chr        1         1         1         1         1         1         1   \
# 1    0.969819  0.641073  0.007309  0.007309  0.007309  0.440074  0.197113
# 2    0.007042  0.007042  0.007042  0.007042  0.007042  0.007042  0.779749
# 3    0.006847  0.335592  0.969358  0.006847  0.659318  0.006847  0.006847
# 4    0.005534  0.005534  0.005534  0.005534  0.005534  0.535278  0.005534
# 5    0.010758  0.010759  0.010757  0.973267  0.320797  0.010759  0.010756
#
# Chr        1         1         1   ...        23        23        23  \
# 1    0.542184  0.554657  0.202043  ...  0.007309  0.515703  0.007309
# 2    0.434676  0.007042  0.007042  ...  0.007042  0.461156  0.007042
# 3    0.006847  0.006847  0.006847  ...  0.553604  0.006847  0.006847
# 4    0.005534  0.005534  0.773311  ...  0.421287  0.005534  0.005534
# 5    0.010758  0.425920  0.010757  ...  0.010758  0.010759  0.973267
#
# Chr        23        23        23        23        23        23        23
# 1    0.969819  0.590108  0.007309  0.007309  0.007309  0.007309  0.007309
# 2    0.007042  0.386752  0.007042  0.969552  0.007042  0.969552  0.007042
# 3    0.006847  0.006847  0.969358  0.006847  0.006847  0.006847  0.006847
# 4    0.005534  0.005534  0.005534  0.005534  0.005534  0.005534  0.005534
# 5    0.010758  0.010758  0.010757  0.010757  0.973267  0.010758  0.973267
#
# [5 rows x 176065 columns]

# %%
clusters = file['Chr'].unique()
palette = list(sns.color_palette("viridis", 23).as_hex())
color_mapping = dict(zip(clusters, palette))
cluster_colors = file['Chr'].map(color_mapping)

# %%
plt.figure(figsize=(18,5))
ax = sns.heatmap(heatmap_df, cmap='coolwarm', vmin=0, vmax=1)
ax.tick_params(axis="both", which="major", labelsize=10)
plt.xlabel('Chromosome', fontsize=16)
plt.ylabel('Signature', fontsize=16)
plt.title("Signature weights per sample", fontsize=20)
plt.savefig('../figures/heatmap.pdf')
plt.show()

# %%
cin = pd.read_table("../data/all_tcga_cin_measures.txt", sep=" ")
cin = cin.set_index('sample_id')
cin = cin.reindex(index=weights_df['Sample'])
cin = cin.reset_index()
cin
# Out:
#               Sample  Telomeric.AI     Mean.size  Interstitial.AI  \
# 0       TCGA-02-0001           6.0  1.993161e+07             18.0
# 1       TCGA-AP-A054           NaN           NaN              NaN
# 2       TCGA-C4-A0F7          24.0  1.787304e+07            117.0
# 3       TCGA-DJ-A3US           0.0           NaN              3.0
# 4       TCGA-TS-A8AI           6.0  1.943115e+07             19.0
# ...              ...           ...           ...              ...
# 176060  TCGA-BR-8368           2.0  5.493895e+07             23.0
# 176061  TCGA-VD-A8KF           1.0  4.379279e+07              0.0
# 176062  TCGA-24-1565          10.0  2.391925e+07              6.0
# 176063  TCGA-AF-2687           7.0  1.225353e+07             22.0
# 176064  TCGA-ZX-AA5X           5.0  2.422092e+07              8.0
#
#            Mean.Size  Whole.chr.AI  Telomeric.LOH   Mean.size.1  \
# 0       1.293457e+07           3.0            2.0  1.788160e+07
# 1                NaN           NaN            NaN           NaN
# 2       9.834940e+06           0.0           14.0  1.985049e+07
# 3       4.811540e+06           0.0            0.0           NaN
# 4       2.256094e+07           1.0            5.0  2.135149e+07
# ...              ...           ...            ...           ...
# 176060  4.674376e+06           0.0            2.0  5.493895e+07
# 176061           NaN           1.0            1.0  4.379279e+07
# 176062  3.849751e+07           0.0            7.0  2.822523e+07
# 176063  2.206762e+07           2.0            3.0  1.750207e+07
# 176064  1.353216e+07           0.0            4.0  2.998270e+07
#
#         Interstitial.LOH   Mean.Size.1  ...    Ploidy  Aberrant.cell.fraction  \
# 0                   11.0  1.464080e+07  ...  2.315302                    0.58
# 1                    NaN           NaN  ...       NaN                     NaN
# 2                   45.0  1.562689e+07  ...  3.270631                    0.62
# 3                    3.0  4.811540e+06  ...  1.998908                    0.79
# 4                   19.0  2.256094e+07  ...  1.790394                    0.53
# ...                  ...           ...  ...       ...                     ...
# 176060              10.0  7.971002e+06  ...  2.039340                    0.70
# 176061               0.0           NaN  ...  2.000909                    0.85
# 176062               5.0  2.809880e+07  ...  2.018231                    0.78
# 176063               9.0  1.823425e+07  ...  3.082829                    0.47
# 176064               6.0  1.477971e+07  ...  4.075048                    0.23
#
#         cancerType   lst   hrd       GII      wGII      FLOH     wFLOH  \
# 0              NaN   9.0   6.0  0.520588  0.462361  0.201262  0.231483
# 1              NaN   NaN   NaN       NaN       NaN       NaN       NaN
# 2              NaN  21.0  22.0  0.704474  0.662600  0.344939  0.355221
# 3              NaN   0.0   0.0  0.007034  0.004985  0.005837  0.003953
# 4              NaN  12.0  13.0  0.262152  0.233425  0.254523  0.222219
# ...            ...   ...   ...       ...       ...       ...       ...
# 176060         NaN   5.0   4.0  0.097600  0.079817  0.072905  0.046652
# 176061         NaN   0.0   1.0  0.179079  0.135451  0.086538  0.059098
# 176062         NaN   3.0   6.0  0.189553  0.221348  0.121219  0.172419
# 176063         NaN   7.0   2.0  0.644621  0.626490  0.108863  0.134760
# 176064         NaN   7.0   7.0  0.144448  0.098912  0.074724  0.081937
#
#         cnt_chr
# 0          52.5
# 1           NaN
# 2          85.0
# 3          43.0
# 4          41.0
# ...         ...
# 176060     45.5
# 176061     44.0
# 176062     42.5
# 176063     64.5
# 176064     90.0
#
# [176065 rows x 21 columns]

# %%
survivaldata = pd.read_table("/home/janneae/TCGA/DerivedData/TCGA_survival_data_clean.txt")
survivaldata = survivaldata.set_index('bcr_patient_barcode')
survivaldata = survivaldata.reindex(index=weights_df['Sample'])
survivaldata = survivaldata.reset_index()

# %%
combined_df = weights_df.reset_index()
combined_df['Age_at_diagnosis'] = survivaldata['age_at_initial_pathologic_diagnosis']
combined_df = combined_df.dropna()
combined_df
# Out:
#          index        Sample  Chr         1         2         3         4  \
# 0            0  TCGA-02-0001    1  0.969819  0.007042  0.006847  0.005534
# 1        55108  TCGA-AP-A054    1  0.641073  0.007042  0.335592  0.005534
# 2        76107  TCGA-C4-A0F7    1  0.007309  0.007042  0.969358  0.005534
# 3        99958  TCGA-DJ-A3US    1  0.007309  0.007042  0.006847  0.005534
# 4       160885  TCGA-TS-A8AI    1  0.007309  0.007042  0.659318  0.005534
# ...        ...           ...  ...       ...       ...       ...       ...
# 176060   74427  TCGA-BR-8368   23  0.007309  0.007042  0.969358  0.005534
# 176061  163506  TCGA-VD-A8KF   23  0.007309  0.969552  0.006847  0.005534
# 176062   12557  TCGA-24-1565   23  0.007309  0.007042  0.006847  0.005534
# 176063   50852  TCGA-AF-2687   23  0.007309  0.969552  0.006847  0.005534
# 176064  176064  TCGA-ZX-AA5X   23  0.007309  0.007042  0.006847  0.005534
#
#                5  Age_at_diagnosis
# 0       0.010758              44.0
# 1       0.010759              64.0
# 2       0.010757              77.0
# 3       0.973267              37.0
# 4       0.320797              58.0
# ...          ...               ...
# 176060  0.010757              84.0
# 176061  0.010757              68.0
# 176062  0.973267              74.0
# 176063  0.010758              57.0
# 176064  0.973267              64.0
#
# [161046 rows x 9 columns]

# %%
combined_cin = weights_df.reset_index()
combined_cin['Telomeric.AI'] = cin['Telomeric.AI']
combined_cin['lst'] = cin['lst']
combined_cin['hrd'] = cin['hrd']
combined_cin['wGII'] = cin['wGII']
combined_cin['ploidy'] = cin['Ploidy']
combined_cin['hrd_score'] = cin['lst'] + cin['Telomeric.AI'] + cin['hrd']
combined_cin['wFLOH'] = cin['wFLOH']
combined_cin = combined_cin.dropna()
combined_cin.head()

# %%
pearsonr(combined_df['1'], combined_df['Age_at_diagnosis'])[1]
# Out:
# 7.283260272240468e-07

# %%
def correlate(survival, cin, val):
    corr_agediag = []
    corr_tel = []
    lst = []
    hrd = []
    hrd_score = []
    ploidy = []
    wGII = []
    wFLOH = []
    
    for i in range(1, 6):
        corr_agediag.append(pearsonr(survival[f'{i}'], survival['Age_at_diagnosis'])[val])
        corr_tel.append(pearsonr(cin[f'{i}'], cin['Telomeric.AI'])[val])
        lst.append(pearsonr(cin[f'{i}'], cin['lst'])[val])
        hrd.append(pearsonr(cin[f'{i}'], cin['hrd'])[val])
        hrd_score.append(pearsonr(cin[f'{i}'], cin['hrd_score'])[val])
        ploidy.append(pearsonr(cin[f'{i}'], cin['ploidy'])[val])
        wGII.append(pearsonr(cin[f'{i}'], cin['wGII'])[val])
        wFLOH.append(pearsonr(cin[f'{i}'], cin['wFLOH'])[val])
    
    corr_df = pd.DataFrame([1, 2, 3, 4, 5], columns=['Signature'])
    corr_df['Telomeric.AI'] = corr_tel
    corr_df['Age_at_diagnosis'] = corr_agediag
    corr_df['LST'] = lst
    corr_df['HRD'] = hrd
    corr_df['HRD_score'] = hrd_score
    corr_df['Ploidy'] = ploidy
    corr_df['wGII'] = wGII
    corr_df['wFLOH'] = wFLOH
    
    corr_df = corr_df.set_index('Signature')
    corr_df = corr_df.transpose()
    
    return corr_df

# %%
corr_df = correlate(combined_df, combined_cin, 0)
pval_df = correlate(combined_df, combined_cin, 1)
corr_df
# Out:
# Signature                1         2         3         4         5
# Telomeric.AI     -0.068835 -0.040357  0.013636  0.171217 -0.052551
# Age_at_diagnosis -0.012343 -0.006174  0.004659  0.016992 -0.001520
# LST              -0.066345 -0.052388  0.035691  0.143819 -0.043814
# HRD              -0.081207 -0.030917  0.047118  0.098993 -0.024602
# HRD_score        -0.077228 -0.045773  0.032680  0.155015 -0.045828
# Ploidy           -0.001406  0.107101 -0.137094  0.168253 -0.092526
# wGII             -0.075615  0.041998 -0.047952  0.167522 -0.055573
# wFLOH            -0.089433  0.030485  0.010865  0.085536 -0.024790

# %%
pval_df = correlate(combined_df, combined_cin, 1)
psig = 0.001/176000

for i in range(1, 5):
    for j in range(1, 8):
        if pval_df[i][j] > psig:
            corr_df[i][j] = 0
corr_df
# Out:
# Signature                1         2         3         4         5
# Telomeric.AI     -0.068835 -0.040357  0.013636  0.171217 -0.052551
# Age_at_diagnosis  0.000000  0.000000  0.000000  0.016992 -0.001520
# LST              -0.066345 -0.052388  0.035691  0.143819 -0.043814
# HRD              -0.081207 -0.030917  0.047118  0.098993 -0.024602
# HRD_score        -0.077228 -0.045773  0.032680  0.155015 -0.045828
# Ploidy            0.000000  0.107101 -0.137094  0.168253 -0.092526
# wGII             -0.075615  0.041998 -0.047952  0.167522 -0.055573
# wFLOH            -0.089433  0.030485  0.000000  0.085536 -0.024790

# %%
palette = sns.diverging_palette(20, 220, as_cmap=True)

f, ax = plt.subplots(figsize=(7, 5))
ax = sns.heatmap(
    corr_df[corr_df!=0],
    # vmin=-0.5, vmax=0.5, 
    cmap=palette,
    square=True,
    linewidths=11)
    
plt.xlabel("Signature", fontsize=12)
ax.tick_params(axis="both", which="major", labelsize=9)
plt.savefig('../figures/correlation_matrix.pdf')
