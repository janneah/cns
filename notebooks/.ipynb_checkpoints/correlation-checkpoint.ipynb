# %%
import pandas as pd
from gensim.models import LdaModel
from gensim import corpora
import seaborn as sns
import matplotlib.pylab as plt

# %%
file = pd.read_table('../steps/discretized_9.features', dtype=str)

# %%
CIN = pd.read_table("/home/janneae/TCGA/DerivedData/TCGA_survival_data_clean.txt")

# %%
CIN.head()
# Out:
#    Unnamed: 0 bcr_patient_barcode type  age_at_initial_pathologic_diagnosis  \
# 0           1        TCGA-OR-A5J1  ACC                                 58.0
# 1           2        TCGA-OR-A5J2  ACC                                 44.0
# 2           3        TCGA-OR-A5J3  ACC                                 23.0
# 3           4        TCGA-OR-A5J4  ACC                                 23.0
# 4           5        TCGA-OR-A5J5  ACC                                 30.0
#
#    gender   race ajcc_pathologic_tumor_stage    clinical_stage  \
# 0    MALE  WHITE                    Stage II  [Not Applicable]
# 1  FEMALE  WHITE                    Stage IV  [Not Applicable]
# 2  FEMALE  WHITE                   Stage III  [Not Applicable]
# 3  FEMALE  WHITE                    Stage IV  [Not Applicable]
# 4    MALE  WHITE                   Stage III  [Not Applicable]
#
#                       histological_type histological_grade  ...  \
# 0  Adrenocortical carcinoma- Usual Type    [Not Available]  ...
# 1  Adrenocortical carcinoma- Usual Type    [Not Available]  ...
# 2  Adrenocortical carcinoma- Usual Type    [Not Available]  ...
# 3  Adrenocortical carcinoma- Usual Type    [Not Available]  ...
# 4  Adrenocortical carcinoma- Usual Type    [Not Available]  ...
#
#    residual_tumor   OS  OS.time  DSS DSS.time  DFI  DFI.time  PFI PFI.time  \
# 0             NaN  1.0   1355.0  1.0   1355.0  1.0     754.0  1.0    754.0
# 1             NaN  1.0   1677.0  1.0   1677.0  NaN       NaN  1.0    289.0
# 2             NaN  0.0   2091.0  0.0   2091.0  1.0      53.0  1.0     53.0
# 3             NaN  1.0    423.0  1.0    423.0  NaN       NaN  1.0    126.0
# 4             NaN  1.0    365.0  1.0    365.0  NaN       NaN  1.0     50.0
#
#   Redaction
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 34 columns]

# %%
lda = LdaModel.load(f'../steps/gensim/lda/lda_t5_f10.model')
file = pd.read_table('../steps/discretized_9.features', dtype=str)
df = file.drop(['Sample', 'Chr'], axis = 1)
listedDf = df.values.tolist()
dirichlet_dict = corpora.Dictionary(listedDf)
bow_corpus = [dirichlet_dict.doc2bow(text) for text in listedDf]

# %%
def create_heatmap(model, df):
    topics = lda.get_document_topics(bow = bow_corpus, minimum_probability = 0)
    
    new_df = pd.DataFrame(df['Sample'])
    new_df['Chr'] = df['Chr']
    new_df['Chr'] = pd.to_numeric(new_df['Chr'])
    
    columns = [[],[],[],[],[]]
    for topic in topics:
        for w in topic:
            columns[w[0]].append(w[1])
    
    new_df['1'] = columns[0]
    new_df['2'] = columns[1]
    new_df['3'] = columns[2]
    new_df['4'] = columns[3]
    new_df['5'] = columns[4]
    new_df = new_df.sort_values(by='Chr')
    return new_df

# %%
heatmap_df = create_heatmap(lda, file)
heatmap_df
# heatmap_dftp = heatmap_df.set_index('Chr')
# heatmap_dftp = heatmap_dftp.transpose()

# %%
clusters = file['Chr'].unique()
palette = list(sns.color_palette("viridis", 23).as_hex())
color_mapping = dict(zip(clusters, palette))
cluster_colors = file['Chr'].map(color_mapping)

# %%
plt.figure(figsize=(18,5))
ax = sns.heatmap(heatmap_dftp, cmap='coolwarm', vmin=0, vmax=1)
ax.tick_params(axis="both", which="major", labelsize=10)
plt.xlabel('Chromosome', fontsize=16)
plt.ylabel('Signature', fontsize=16)
plt.title("Signature weights per sample", fontsize=20)
plt.savefig('../figures/heatmap.pdf')
plt.show()

# %%
heatmap_df['Sample'] = file['Sample'] 
heatmap_df.head()
# Out:
#             1         2         3         4         5        Sample
# Chr
# 1    0.005398  0.648019  0.007934  0.004113  0.334536  TCGA-02-0001
# 1    0.005339  0.007851  0.290967  0.004067  0.691776  TCGA-02-0001
# 1    0.005319  0.007823  0.007817  0.004052  0.974989  TCGA-02-0001
# 1    0.005256  0.976052  0.007724  0.004004  0.006964  TCGA-02-0001
# 1    0.005725  0.701799  0.008414  0.004361  0.279702  TCGA-02-0001

# %%
Top15['Citable docs per Capita'].corr(Top15['Energy Supply per Capita'])
